# %% [markdown]
# # Populating DWH

# %% [markdown]
# ## Import libraries

# %%
import sqlite3
import pandas as pd

# %% [markdown]
# ## Define connections

# %%
SDM = sqlite3.connect('../SDM/BikeToDriveSDM.db')
DWH = sqlite3.connect('BikeToDriveDWH.db')
